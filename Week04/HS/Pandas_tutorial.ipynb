# %%
import pandas as pd
file_path = '/Users/worldneedscat/data_webprogramming/'
file_name = 'survey_results_public.csv'
file_schema_name = 'survey_results_schema.csv'

# %%
people = {'first': ['Corey', 'Jane', 'John', 'Adam'], 
          'last': ['Schafer', 'Doe', 'Doe', 'Doe'], 
          'email': ['CoreyMSchafer@gmail.com', 'JaneDoe@email.com', 'JohnDoe@email.com', 'AdamDoe@email.com']}

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3   Adam      Doe        AdamDoe@email.com

# %%
df.sort_values(by=['last', 'first'], ascending=False)
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 2   John      Doe        JohnDoe@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 3   Adam      Doe        AdamDoe@email.com

# %%
df.sort_values(by=['last', 'first'], ascending=[False, True], inplace=True)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 3   Adam      Doe        AdamDoe@email.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#    first     last                    email
# 0  Corey  Schafer  CoreyMSchafer@gmail.com
# 1   Jane      Doe        JaneDoe@email.com
# 2   John      Doe        JohnDoe@email.com
# 3   Adam      Doe        AdamDoe@email.com

# %%
df['last'].sort_values()
# Out:
# 1        Doe
# 2        Doe
# 3        Doe
# 0    Schafer
# Name: last, dtype: object

# %%
df = pd.read_csv(file_path+file_name, index_col='Respondent')
df_schema = pd.read_csv(file_path+file_schema_name, index_col='Column')
pd.set_option('display.max_columns', 85)
pd.set_option('display.max_rows', 85)

# %%
df.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
df.sort_values(by=['Country', 'ConvertedComp'], ascending=[True, False], inplace=True)

# %%
df[['Country','ConvertedComp']].head(50)
# Out:
#            Country  ConvertedComp
# 62723  Afghanistan      1000000.0
# 50172  Afghanistan       153216.0
# 39018  Afghanistan        19152.0
# 58082  Afghanistan        17556.0
# 7056   Afghanistan        14364.0
# 22327  Afghanistan         7980.0
# 48122  Afghanistan         4464.0
# 10697  Afghanistan         3996.0
# 8112   Afghanistan         1596.0
# 29560  Afghanistan         1116.0
# 28470  Afghanistan            0.0
# 719    Afghanistan            0.0
# 85185  Afghanistan            NaN
# 50437  Afghanistan            NaN
# 88340  Afghanistan            NaN
# 88735  Afghanistan            NaN
# 6391   Afghanistan            NaN
# 39754  Afghanistan            NaN
# 88181  Afghanistan            NaN
# 62124  Afghanistan            NaN
# 49377  Afghanistan            NaN
# 32971  Afghanistan            NaN
# 60559  Afghanistan            NaN
# 85827  Afghanistan            NaN
# 88033  Afghanistan            NaN
# 26189  Afghanistan            NaN
# ...

# %%
df['ConvertedComp'].nlargest(10)
# Out:
# 25833    2000000.0
# 87353    2000000.0
# 21895    2000000.0
# 28080    2000000.0
# 72274    2000000.0
# 77665    2000000.0
# 79701    2000000.0
# 51798    2000000.0
# 75088    2000000.0
# 32056    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
df
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
df['ConvertedComp'].median()
# Out:
# 57287.0

# %%
df.describe()
# Out:
#          Respondent     CompTotal  ConvertedComp   WorkWeekHrs    CodeRevHrs  \
# count  88883.000000  5.594500e+04   5.582300e+04  64503.000000  49790.000000
# mean   44442.000000  5.519014e+11   1.271107e+05     42.127197      5.084308
# std    25658.456325  7.331926e+13   2.841523e+05     37.287610      5.513931
# min        1.000000  0.000000e+00   0.000000e+00      1.000000      0.000000
# 25%    22221.500000  2.000000e+04   2.577750e+04     40.000000      2.000000
# 50%    44442.000000  6.200000e+04   5.728700e+04     40.000000      4.000000
# 75%    66662.500000  1.200000e+05   1.000000e+05     44.750000      6.000000
# max    88883.000000  1.000000e+16   2.000000e+06   4850.000000     99.000000
#
#                 Age
# count  79210.000000
# mean      30.336699
# std        9.178390
# min        1.000000
# 25%       24.000000
# 50%       29.000000
# 75%       35.000000
# max       99.000000

# %%
df.Country.value_counts()
# Out:
# United States            20949
# India                     9061
# Germany                   5866
# United Kingdom            5737
# Canada                    3395
#                          ...
# Dominica                     1
# Niger                        1
# Sao Tome and Principe        1
# North Korea                  1
# Papua New Guinea             1
# Name: Country, Length: 179, dtype: int64

# %%
df_schema.loc['SocialMedia']
# Out:
# QuestionText    What social media site do you use the most?
# Name: SocialMedia, dtype: object

# %%
country_group = df.groupby(['Country'])

# %%
country_group.get_group('South Korea')
# Out:
#                                         MainBranch Hobbyist  \
# Respondent
# 112                 I am a developer by profession      Yes
# 528                 I am a developer by profession      Yes
# 641                 I am a developer by profession       No
# 966                 I am a developer by profession      Yes
# 1708                I am a developer by profession       No
# ...                                            ...      ...
# 88233               I am a developer by profession      Yes
# 88234               I am a developer by profession      Yes
# 88602               I am a developer by profession      Yes
# 88674       I am a student who is learning to code      Yes
# 9115                                           NaN      Yes
#
#                                                   OpenSourcer  \
# Respondent
# 112                                Once a month or more often
# 528                                                     Never
# ...

# %%
filt = df.Country == 'South Korea'
df[filt].nlargest(10, 'ConvertedComp').ConvertedComp
# Out:
# Respondent
# 44781    1000000.0
# 31943     664824.0
# 51790     461088.0
# 9841      375300.0
# 55477     215000.0
# 55258     125000.0
# 8372      111698.0
# 88602     107230.0
# 16313      89358.0
# 641        85788.0
# Name: ConvertedComp, dtype: float64

# %%
country_group.get_group('South Korea')['SocialMedia'].value_counts()
# Out:
# YouTube                     57
# Facebook                    29
# Twitter                     19
# Instagram                   15
# I don't use social media    14
# Reddit                      12
# LinkedIn                     4
# Weibo 新浪微博                   1
# Name: SocialMedia, dtype: int64

# %%
country_group['SocialMedia'].value_counts().loc['South Korea']
# Out:
# SocialMedia
# YouTube                     57
# Facebook                    29
# Twitter                     19
# Instagram                   15
# I don't use social media    14
# Reddit                      12
# LinkedIn                     4
# Weibo 新浪微博                   1
# Name: SocialMedia, dtype: int64
